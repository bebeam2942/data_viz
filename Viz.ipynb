# %% [markdown]
# <a href="https://colab.research.google.com/github/bebeam2942/data_viz/blob/main/Viz.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd

# %%
df = pd.read_csv ('https://raw.github.com/pandas-dev/pandas/master/pandas/tests/io/data/csv/iris.csv')
df
# Out:
#      SepalLength  SepalWidth  PetalLength  PetalWidth            Name
# 0            5.1         3.5          1.4         0.2     Iris-setosa
# 1            4.9         3.0          1.4         0.2     Iris-setosa
# 2            4.7         3.2          1.3         0.2     Iris-setosa
# 3            4.6         3.1          1.5         0.2     Iris-setosa
# 4            5.0         3.6          1.4         0.2     Iris-setosa
# ..           ...         ...          ...         ...             ...
# 145          6.7         3.0          5.2         2.3  Iris-virginica
# 146          6.3         2.5          5.0         1.9  Iris-virginica
# 147          6.5         3.0          5.2         2.0  Iris-virginica
# 148          6.2         3.4          5.4         2.3  Iris-virginica
# 149          5.9         3.0          5.1         1.8  Iris-virginica
#
# [150 rows x 5 columns]

# %% [markdown]
# #Parallel Coordinates

# %%
pd.plotting.parallel_coordinates(df, 'Name', color=('#556270', '#4ECDC4', '#C7F464')) ;

# %%
pd.plotting.parallel_coordinates(df, 'Name', color=('#b390d8', '#76a0e5', '#dc4982')) ;

# %% [markdown]
# ### ปรับ Parallel Coordinates

# %%
pd.plotting.parallel_coordinates(df, 'Name', color=('r', 'g', 'b')) ; #ตัวย่อยของสี R G B W C M Y K

# %%
pd.plotting.parallel_coordinates(df, 'Name', color=((1,0.8,0),(0,0.7,0),(0.6,0,1)))  #rgb

# %%
pd.plotting.parallel_coordinates(df, 'Name', color=cool) ;
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-23-62dee91458e1> in <module>()
# ----> 1 pd.plotting.parallel_coordinates(df, 'Name', color=cool) ;
#
# NameError: name 'cool' is not defined

# %% [markdown]
# # เริ่ม Matplotlib

# %%
from matplotlib import  pyplot as plt

# %% [markdown]
# ## แปลง data จาก pandas dataframe เป็น numpy array

# %%
np_data = df.iloc[:, :-1].to_numpy()

# %% [markdown]
# ## visualiza array data ด้วย pixel

# %%
import matplotlib

# %%
matplotlib.rcParams['figure.figsize'] = [15,15] #กำหนดขนาดของ figure
plt.imshow(np_data[:10,:],interpolation='nearest' ) #imshow คือ โชว์ในเป็นรูปภาพ

# %%
plt.subplot(1,3,2) #supplot (มีกี่แถว, มีกี่หลัก , เป็นตัวที่เท่าไหร่)
plt.imshow(np_data[:10,:],interpolation='nearest' )
plt.subplot(1,3,3)
plt.imshow(np_data[10:20,:],interpolation='nearest' ) ;
